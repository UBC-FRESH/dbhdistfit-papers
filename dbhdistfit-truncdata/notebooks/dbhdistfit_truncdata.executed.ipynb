# %% [markdown]
# # Truncated Diameter Fitting Reproducibility Notebook
#
# This notebook mirrors the scripted pipeline for the truncated fixed-area permanent sample plot dataset. Run the cells top-to-bottom to regenerate the processed data, tables, and diagnostic figures.

# %% [markdown]
# ## Environment setup
#
# Ensure the project virtual environment is active (`make env`) and required data are available (the `data/processed/` folder is generated on the fly).

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path("..").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print(f"Project root: {PROJECT_ROOT}")
# Out:
# Project root: /home/gep/projects/dbhdistfit-papers/dbhdistfit-truncdata

# %%
from scripts import preprocess_data, generate_tables, generate_figures

preprocess_data.main()
generate_tables.main()
generate_figures.main()
# Out:
# [preprocess] wrote /home/gep/projects/dbhdistfit-papers/dbhdistfit-truncdata/data/processed/truncation_binned.parquet (and CSV twin)
# [tables] wrote /home/gep/projects/dbhdistfit-papers/dbhdistfit-truncdata/tables/method_comparison.csv, /home/gep/projects/dbhdistfit-papers/dbhdistfit-truncdata/tables/method_comparison.tex, and /home/gep/projects/dbhdistfit-papers/dbhdistfit-truncdata/tables/method_comparison.json
# [figures] wrote /home/gep/projects/dbhdistfit-papers/dbhdistfit-truncdata/figures/spruce_pine_fir_softwood.pdf and PNG twin
# [figures] wrote /home/gep/projects/dbhdistfit-papers/dbhdistfit-truncdata/figures/birch_mixedwood.pdf and PNG twin
# [figures] wrote /home/gep/projects/dbhdistfit-papers/dbhdistfit-truncdata/figures/maple_hardwood.pdf and PNG twin
# [figures] wrote combined figure /home/gep/projects/dbhdistfit-papers/dbhdistfit-truncdata/figures/diameter_comparison.pdf and PNG twin

# %%
import pandas as pd
from IPython.display import display
from scripts.common import project_path

comparison = pd.read_csv(project_path("tables", "method_comparison.csv"))
display(comparison.head())
# Out:
#   species_group cover_type distribution                     stage1_params  \
# 0           auf          f      weibull   a = 0.28±0.00, beta = 0.10±0.00
# 1           auf          m        gamma  beta = 10.90±4.35, p = 0.71±0.59
# 2           auf          r        gamma  beta = 0.37±0.07, p = 33.14±6.39
# 3           boj          f        gamma  beta = 24.72±9.99, p = 0.92±0.36
# 4           boj          m      weibull  a = 1.02±0.14, beta = 21.50±1.55
#
#                       stage2_params  aicc_stage2
# 0   a = 0.28±0.00, beta = 0.10±0.00  -247.362794
# 1  beta = 10.90±1.13, p = 0.71±0.05  -195.474608
# 2  beta = 0.37±0.05, p = 33.14±4.47   -71.392055
# 3  beta = 24.72±2.67, p = 0.92±0.08  -266.249830
# 4  a = 1.02±0.04, beta = 21.50±1.46  -288.458429

# %%
from IPython.display import Image
from scripts.common import project_path

Image(filename=str(project_path("figures", "spruce_pine_fir_softwood.png")))
